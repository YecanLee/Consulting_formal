# %%
import webdataset as wds
import json
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

def show_sample_from_shard(shard_path, max_images: int = 10):
    dataset = wds.WebDataset(shard_path).decode("pil").to_tuple("jpg", "json")

    for idx, (image, json_bytes) in enumerate(dataset):
        description = json_bytes["description"]
        display(Markdown(f"### 🎨 Image {idx + 1} Description\n{description}"))
        plt.imshow(image)
        plt.axis("off")
        plt.show()
    
        if idx + 1 >= max_images:
            break

# %%
show_sample_from_shard("web_dataset/baroque-00000.tar")
# Out:
# /home/ra69nat/anaconda3/envs/image/lib/python3.11/site-packages/webdataset/compat.py:389: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn(
# ### 🎨 Image 1 Description
# This Baroque ceiling painting showcases several plump putti dynamically floating amidst a cloudy, atmospheric sky, a common motif of the period. These idealized figures, rendered with soft chiaroscuro, hold symbolic objects such as laurel wreaths and flowers, likely conveying themes of triumph, love, or fertility. The expansive, theatrical composition and celestial setting are characteristic of 17th and 18th-century ceiling decoration, intended to uplift and impress the viewer.
# ### 🎨 Image 2 Description
# ...
